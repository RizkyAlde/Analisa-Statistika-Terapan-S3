# %%
#Buatlah intrumen kuesioner, dan lakukan uji Validitas dan Reliabilitas, dilanjutkan analisis faktor (Laporan Resmi ke-1)

# %%
import pandas as pd
df = pd.read_csv('data_studi.csv')

# %%
dfq = df.drop(columns = (['Timestamp', 'Nama Lengkap', 'NRP', 'Program Studi']))
dfq
# Out:
#     Seberapa strategis lokasi PENS?  \
# 0                                 3
# 1                                 3
# 2                                 3
# 3                                 3
# 4                                 4
# 5                                 1
# 6                                 3
# 7                                 4
# 8                                 2
# 9                                 3
# 10                                3
# 11                                3
# 12                                3
# 13                                3
# 14                                3
# 15                                3
# 16                                4
# 17                                4
# 18                                3
# 19                                3
# 20                                2
# 21                                2
# 22                                3
# 23                                3
# 24                                4
# ...

# %%
dfs['Total_Skor'] = dfs.sum(axis = 1, skipna = True)
dfs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dfs['Total_Skor'] = dfs.sum(axis = 1, skipna = True)
#       2 dfs
#
# NameError: name 'dfs' is not defined
